# %%
# Prepare your workstation.
import pandas as pd

# Create the data for the DataFrame.
raw_data = {'Name': ['Thando Sinuka', 'Divya Patterson',
                     'Simon De Wit', 'Peter Black',
                     'Noncedo Dlamini', 'David Ackerman',
                     'Eugene du Toit', 'Amaira Patteri',
                     'Monica Le Blanc', 'Richard Fortress'],
            'Age':[29, 26, 25, 23, 30, 35, 25, 27, 24, 32],
            'Qualification': ['PhD', 'MSc', 'MBA', 'BSc',
                              'MCom', 'BCom', 'PhD', 'MBA', 
                              'MCom', 'BCom'],
            'Country': ['South Africa', 'Singapore', 'United Kingdom',
                        'Australia', 'Lesotho', 'United Kingdom',
                        'Canada', 'India', 'France', 'Canada']}

# Specify the row_labels.
row_labels = ['2021/0562/3215', '2021/2136/2132',
              '2021/0021/5987', '2021/3165/0468',
              '2021/0132/5496', '2021/3698/1346',
              '2021/0147/9632', '2021/6549/1324',
              '2021/9513/3579', '2021/3491/7916']

# Specify the column names.
students_updated = pd.DataFrame (raw_data,
                                 columns = ['Name', 'Age', 'Qualification',
                                            'Country', 'Test 1', 'Tutorial 1',
                                            'Test 2', 'Tutorial 2', 'Test 3',
                                            'Tutorial 3', 'Final mark', 'Pass'],

                                 # specify index = row_labels
                                 index = row_labels)


students_updated ['Test 1'] = [82, 90, 75, 70, 88, 65, 72, 76, 85, 68]
students_updated ['Tutorial 1'] = [80, 75, 79, 69, 82, 68, 90, 84, 83, 79]

students_updated
# Out:
#                             Name  Age Qualification         Country  Test 1  \
# 2021/0562/3215     Thando Sinuka   29           PhD    South Africa      82
# 2021/2136/2132   Divya Patterson   26           MSc       Singapore      90
# 2021/0021/5987      Simon De Wit   25           MBA  United Kingdom      75
# 2021/3165/0468       Peter Black   23           BSc       Australia      70
# 2021/0132/5496   Noncedo Dlamini   30          MCom         Lesotho      88
# 2021/3698/1346    David Ackerman   35          BCom  United Kingdom      65
# 2021/0147/9632    Eugene du Toit   25           PhD          Canada      72
# 2021/6549/1324    Amaira Patteri   27           MBA           India      76
# 2021/9513/3579   Monica Le Blanc   24          MCom          France      85
# 2021/3491/7916  Richard Fortress   32          BCom          Canada      68
#
#                 Tutorial 1 Test 2 Tutorial 2 Test 3 Tutorial 3 Final mark Pass
# 2021/0562/3215          80    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/2136/2132          75    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/0021/5987          79    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/3165/0468          69    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/0132/5496          82    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/3698/1346          68    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/0147/9632          90    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/6549/1324          84    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/9513/3579          83    NaN        NaN    NaN        NaN        NaN  NaN
# 2021/3491/7916          79    NaN        NaN    NaN        NaN        NaN  NaN

# %%
students_updated['Tutorial 2'] = [80, 75, 79, 69, 82, 68, 90, 84, 83, 79]

# %%
students_updated
# Out:
#                             Name  Age Qualification         Country  Test 1  \
# 2021/0562/3215     Thando Sinuka   29           PhD    South Africa      82
# 2021/2136/2132   Divya Patterson   26           MSc       Singapore      90
# 2021/0021/5987      Simon De Wit   25           MBA  United Kingdom      75
# 2021/3165/0468       Peter Black   23           BSc       Australia      70
# 2021/0132/5496   Noncedo Dlamini   30          MCom         Lesotho      88
# 2021/3698/1346    David Ackerman   35          BCom  United Kingdom      65
# 2021/0147/9632    Eugene du Toit   25           PhD          Canada      72
# 2021/6549/1324    Amaira Patteri   27           MBA           India      76
# 2021/9513/3579   Monica Le Blanc   24          MCom          France      85
# 2021/3491/7916  Richard Fortress   32          BCom          Canada      68
#
#                 Tutorial 1 Test 2  Tutorial 2 Test 3 Tutorial 3 Final mark  \
# 2021/0562/3215          80    NaN          80    NaN        NaN        NaN
# 2021/2136/2132          75    NaN          75    NaN        NaN        NaN
# 2021/0021/5987          79    NaN          79    NaN        NaN        NaN
# 2021/3165/0468          69    NaN          69    NaN        NaN        NaN
# 2021/0132/5496          82    NaN          82    NaN        NaN        NaN
# 2021/3698/1346          68    NaN          68    NaN        NaN        NaN
# 2021/0147/9632          90    NaN          90    NaN        NaN        NaN
# 2021/6549/1324          84    NaN          84    NaN        NaN        NaN
# 2021/9513/3579          83    NaN          83    NaN        NaN        NaN
# 2021/3491/7916          79    NaN          79    NaN        NaN        NaN
#
#                Pass
# 2021/0562/3215  NaN
# 2021/2136/2132  NaN
# 2021/0021/5987  NaN
# 2021/3165/0468  NaN
# 2021/0132/5496  NaN
# 2021/3698/1346  NaN
# 2021/0147/9632  NaN
# 2021/6549/1324  NaN
# 2021/9513/3579  NaN
# 2021/3491/7916  NaN

# %%
tut2  = [80, 75, 76, 74, 80, 75, 80, 84, 81,80]

# %%
n_data = []
for i in range(len(students_updated["Name"])):
    mapOld_New = [students_updated.iloc[i]["Tutorial 2"]] + [tut2[i]]
    n_data = n_data + [mapOld_New]
updateMap = dict(n_data)

# %%
students_updated["tut2"] = students_updated["Tutorial 2"].map(updateMap)

# %%
# Reorder columns.
students_updated = students_updated [['Name', 'Age', 'Qualification', 
                                     'Country', 'Test 1', 'Tutorial 1',
                                     'Test 2', 'Tutorial 2', 'tut2', 
                                     'Test 3', 'Tutorial 3', 'Final mark',
                                     'Pass']]

# %%
students_updated
# Out:
#                             Name  Age Qualification         Country  Test 1  \
# 2021/0562/3215     Thando Sinuka   29           PhD    South Africa      82
# 2021/2136/2132   Divya Patterson   26           MSc       Singapore      90
# 2021/0021/5987      Simon De Wit   25           MBA  United Kingdom      75
# 2021/3165/0468       Peter Black   23           BSc       Australia      70
# 2021/0132/5496   Noncedo Dlamini   30          MCom         Lesotho      88
# 2021/3698/1346    David Ackerman   35          BCom  United Kingdom      65
# 2021/0147/9632    Eugene du Toit   25           PhD          Canada      72
# 2021/6549/1324    Amaira Patteri   27           MBA           India      76
# 2021/9513/3579   Monica Le Blanc   24          MCom          France      85
# 2021/3491/7916  Richard Fortress   32          BCom          Canada      68
#
#                 Tutorial 1 Test 2  Tutorial 2  tut2 Test 3 Tutorial 3  \
# 2021/0562/3215          80    NaN          80    80    NaN        NaN
# 2021/2136/2132          75    NaN          75    75    NaN        NaN
# 2021/0021/5987          79    NaN          79    80    NaN        NaN
# 2021/3165/0468          69    NaN          69    74    NaN        NaN
# 2021/0132/5496          82    NaN          82    80    NaN        NaN
# 2021/3698/1346          68    NaN          68    75    NaN        NaN
# 2021/0147/9632          90    NaN          90    80    NaN        NaN
# 2021/6549/1324          84    NaN          84    84    NaN        NaN
# 2021/9513/3579          83    NaN          83    81    NaN        NaN
# 2021/3491/7916          79    NaN          79    80    NaN        NaN
#
#                Final mark Pass
# 2021/0562/3215        NaN  NaN
# 2021/2136/2132        NaN  NaN
# 2021/0021/5987        NaN  NaN
# 2021/3165/0468        NaN  NaN
# 2021/0132/5496        NaN  NaN
# 2021/3698/1346        NaN  NaN
# 2021/0147/9632        NaN  NaN
# 2021/6549/1324        NaN  NaN
# 2021/9513/3579        NaN  NaN
# 2021/3491/7916        NaN  NaN

# %%
fitness = pd.read_csv("daily_activity.csv")

# %%
fit_stat =fitness.describe()

# %%
fit_stat.index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
fit_stat
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# min                    0.000000            0.000000                  0.000000
# 25%                    0.000000            0.000000                  0.000000
# 50%                    0.000000            0.210000                  0.240000
# 75%                    0.000000            2.052500                  0.800000
# max                    4.942142           21.920000                  6.480000
#
#        LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# count           940.000000               940.000000         940.000000
# mean              3.340819                 0.001606          21.164894
# std               2.040655                 0.007346          32.844803
# min               0.000000                 0.000000           0.000000
# 25%               1.945000                 0.000000           0.000000
# 50%               3.365000                 0.000000           4.000000
# 75%               4.782500                 0.000000          32.000000
# max              10.710000                 0.110000         210.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count           940.000000            940.000000        940.000000
# mean             13.564894            192.812766        991.210638
# std              19.987404            109.174700        301.267437
# min               0.000000              0.000000          0.000000
# 25%               0.000000            127.000000        729.750000
# 50%               6.000000            199.000000       1057.500000
# 75%              19.000000            264.000000       1229.500000
# max             143.000000            518.000000       1440.000000
#
#           Calories
# count   940.000000
# mean   2303.609574
# std     718.166862
# min       0.000000
# 25%    1828.500000
# 50%    2134.000000
# 75%    2793.250000
# max    4900.000000

# %%
# max = Returns max of a column
print(fitness['TotalDistance'].max())

# min = Returns min of a column
print(fitness['TotalDistance'].min())

# sum = Returns sum of a column 
print(fitness['TotalDistance'].sum())
# Out:
# 28.0300006866455
# 0.0
# 5160.31999460049

# %%
#1st Quartile of TotalStep
q1 = fitness["TotalSteps"].quantile(0.25)
q3 = fitness["TotalSteps"].quantile(0.75)
iqr_totalSteps = q3-q1
print("The inter-quantile-range is {2} with 25% Quantile = {0} and 75% Quantile = {1}".format(q1,q3, iqr_totalSteps))
# Out:
# The inter-quantile-range is 6937.25 with 25% Quantile = 3789.75 and 75% Quantile = 10727.0

# %%
fitness.describe(include=["object", "bool"])
# Out:
#        ActivityDate
# count           940
# unique           31
# top       4/12/2016
# freq             33

# %%
fitness.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
movies = pd.read_excel("movies.xlsx")
ott = pd.read_csv("ott.csv")

# %%
movies.head()
# Out:
#                             Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0                       Inception  2010  13+   8.8             0.87
# 1                      The Matrix  1999  18+   8.7             0.87
# 2          Avengers: Infinity War  2018  13+   8.5             0.84
# 3              Back to the Future  1985   7+   8.5             0.96
# 4  The Good, the Bad and the Ugly  1966  18+   8.8             0.97
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# 1                 United States                  English    136.0
# 2                 United States                  English    149.0
# 3                 United States                  English    116.0
# 4      Italy,Spain,West Germany                  Italian    161.0

# %%
moviesNums = movies.select_dtypes('number')

# %%
moviesNums.head()
# Out:
#    Year  IMDb  Rotten Tomatoes  Runtime
# 0  2010   8.8             0.87    148.0
# 1  1999   8.7             0.87    136.0
# 2  2018   8.5             0.84    149.0
# 3  1985   8.5             0.96    116.0
# 4  1966   8.8             0.97    161.0

# %%
del moviesNums["Year"]

# %%
q1 = pd.Series(moviesNums.quantile(0.25))
q3 = pd.Series(moviesNums.quantile(0.75))
quantile = pd.concat([q1,q3], axis=1)
quantile["iqr"] = quantile[0.75]-quantile[0.25]

# %%
quantile
# Out:
#                   0.25    0.75    iqr
# IMDb              5.10    6.90   1.80
# Rotten Tomatoes   0.44    0.88   0.44
# Runtime          82.00  104.00  22.00

# %%
quantile = pd.concat([q1,q3], axis=1)

# %%
data
# Out:
#                   0.25    0.75
# IMDb              5.10    6.90
# Rotten Tomatoes   0.44    0.88
# Runtime          82.00  104.00

# %%
data
# Out:
# [IMDb                5.10
#  Rotten Tomatoes     0.44
#  Runtime            82.00
#  Name: 0.25, dtype: float64,
#  IMDb                 6.90
#  Rotten Tomatoes      0.88
#  Runtime            104.00
#  Name: 0.75, dtype: float64]

# %%
data
# Out:
# IMDb                 5.10
# Rotten Tomatoes      0.44
# Runtime             82.00
# IMDb                 6.90
# Rotten Tomatoes      0.88
# Runtime            104.00
# dtype: float64

# %%
iqr
# Out:
# Empty DataFrame
# Columns: [(5.1, 6.9), (0.44, 0.88), (82.0, 104.0)]
# Index: []

# %%
q1
# Out:
# IMDb                5.10
# Rotten Tomatoes     0.44
# Runtime            82.00
# Name: 0.25, dtype: float64
